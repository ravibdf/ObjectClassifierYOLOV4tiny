# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive/MyDrive/yolov4-tiny
# Out:
# backup	   chart_yolov3-tiny.png	custom_data.zip
# bad.list   chart_yolov4-tiny_ambev.png	custom_weight
# chart.png  custom_data			darknet

# %%
# Descompactando as imagens do banco de dados na nuvem, somente é necessário fazer uma vez
#  !unzip gdrive/MyDrive/yolov4-tiny/custom_data.zip -d gdrive/MyDrive/yolov4-tiny

# %%
# Separando o dataset em treino e teste
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# Criando os arquivos necessários para executar o algoritmo
# !python custom_data/creating-files-data-and-name.py

# %%
# Copiando o código do darknet, somente é necessário fazer uma vez
# !git clone 'https://github.com/AlexeyAB/darknet' 'gdrive/MyDrive/yolov4-tiny/darknet'

# %%
# Alterando o arquivo Makefile para utilizar a GPU
# %cd 'gdrive/MyDrive/yolov4-tiny/darknet'

# !sed -i 's/OPENCV=1/OPENCV=1/' Makefile
# !sed -i 's/GPU=1/GPU=1/' Makefile
# !sed -i 's/CUDNN=1/CUDNN=1/' Makefile
# Out:
# /content/gdrive/MyDrive/yolov4-tiny/darknet

# %%
# Make do darknet
# !chmod +x Makefile
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# Alterando permissão da pasta
# %cd ..
# !ls
# !chmod +x ./darknet/darknet
# Out:
# backup	   chart_yolov3-tiny.png	custom_data.zip
# bad.list   chart_yolov4-tiny_ambev.png	custom_weight
# chart.png  custom_data			darknet

# %%
#  Treinando a rede com o yolov4-tine
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov4-tiny_ambev.cfg custom_weight/yolov4-tiny.conv.29 -dont_show

# %%
# Caso a conexão seja perdidade com o colab, é possível voltar a simulação do último backup dos pesos.
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3-tiny.cfg backup/yolov3-tiny_last.weights -dont_show
# Out:
#  GPU isn't used
#  OpenCV version: 3.2.0
# yolov3-tiny
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
# ...

# %%
#  Calculando as métricas como mAP, acurácia, recall para IOU -> 50%
# !darknet/darknet detector map custom_data/labelled_data.data darknet/cfg/yolov4-tiny_ambev.cfg darknet/backup/yolov4-tiny_ambev_final.weights -dont_show -ext_output
# Out:
#  GPU isn't used
#  OpenCV version: 3.2.0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
#    9 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...

# %%
# #  Calculando as métricas como mAP, acurácia, recall para IOU -> 75%
# !darknet/darknet detector map custom_data/labelled_data.data darknet/cfg/yolov4-tiny_ambev.cfg darknet/backup/yolov4-tiny_ambev_final.weights -iou_thresh 0.75
# Out:
#  GPU isn't used
#  OpenCV version: 3.2.0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
#    9 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...
